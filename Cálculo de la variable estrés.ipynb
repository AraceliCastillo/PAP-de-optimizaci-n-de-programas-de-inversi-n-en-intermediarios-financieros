# %%
#Importar Librerías 
import pandas as pd 
import numpy as np

# %%
#Lectura de la base de datos
data=pd.read_excel('data.xlsx', sheet_name='IIEG_E_1') 

data = data.replace({"Más de 52": 52, "De 26 a 52": 26, "No aplica": 100, "No contesto": 101, "No sé":102, "Más de un año":12})
estres = np.zeros(len(data))#Agregar columna de variable a predicir

# %%
#ventas_porcentaje
for i in range(0, len(data)):
    if data['ventas_porcentaje'][i]>0 and data['ventas_porcentaje'][i]<=25:
        estres[i] += 1
    if data['ventas_porcentaje'][i]>25 and data['ventas_porcentaje'][i]<=50:
        estres[i] += 2
    if data['ventas_porcentaje'][i]>50 and data['ventas_porcentaje'][i]<=75:
        estres[i] += 3
    if data['ventas_porcentaje'][i]>75 and data['ventas_porcentaje'][i]<=100:
        estres[i] += 4
#perdidas_porcentaje
for i in range(0, len(data)):
    if data['perdidas_porcentaje'][i]>0 and data['perdidas_porcentaje'][i]<=25:
        estres[i] += 1
    if data['perdidas_porcentaje'][i]>25 and data['perdidas_porcentaje'][i]<=50:
        estres[i] += 2
    if data['perdidas_porcentaje'][i]>50 and data['perdidas_porcentaje'][i]<=75:
        estres[i] += 3
    if data['perdidas_porcentaje'][i]>75 and data['perdidas_porcentaje'][i]<=100:
        estres[i] += 4
#capacidad
for i in range(0, len(data)):
    if data['capacidad'][i]>0 and data['capacidad'][i]<=25:
        estres[i] += 1
    if data['capacidad'][i]>25 and data['capacidad'][i]<=50:
        estres[i] += 2
    if data['capacidad'][i]>50 and data['capacidad'][i]<=75:
        estres[i] += 3
    if data['capacidad'][i]>75 and data['capacidad'][i]<=100:
        estres[i] += 4
#cerrar
for i in range(0, len(data)):
    if data['cerrar'][i] == 'Sí':
        estres[i] += 2
    if data['cerrar'][i] == 'No':
        estres[i] += 0
#despidos
for i in range(0, len(data)):
    if data['despidos'][i] == 'Sí' or data['despidos'][i] == 'No, pero lo está considerando':
        estres[i] += 2
    if data['despidos'][i] == 'No' or data['despidos'][i] == 'No cuenta con personal':
        estres[i] += 0
    if data['despidos'][i] == 'No, pero lo hará en los próximos días':
        estres[i] += 3
        
#plantilla_porcentaje
for i in range(0, len(data)):
    if data['plantilla_porcentaje'][i]>0 and data['plantilla_porcentaje'][i]<=25:
        estres[i] += 1
    if data['plantilla_porcentaje'][i]>25 and data['plantilla_porcentaje'][i]<=50:
        estres[i] += 2
    if data['plantilla_porcentaje'][i]>50 and data['plantilla_porcentaje'][i]<=75:
        estres[i] += 3
    if data['plantilla_porcentaje'][i]>75 and data['plantilla_porcentaje'][i]<=100:
        estres[i] += 4
        
#pago_salarios
for i in range(0, len(data)):
    if data['pago_salarios'][i] == 100 or data['pago_salarios'][i] == 101 or data['pago_salarios'][i] == 102:
        estres[i] += 0
    if data['pago_salarios'][i]>0 and data['pago_salarios'][i]<=6:
        estres[i] += 1
    if data['pago_salarios'][i]>6 and data['pago_salarios'][i]<=12:
        estres[i] += 2
    if data['pago_salarios'][i]>12 and data['pago_salarios'][i]<=18:
        estres[i] += 3
    if data['pago_salarios'][i]>18 and data['pago_salarios'][i]<=24:
        estres[i] += 4
        
#pago_impuestos
for i in range(0, len(data)):
    if data['pago_impuestos'][i] == 100 or data['pago_impuestos'][i] == 101 or data['pago_impuestos'][i] == 102:
        estres[i] += 0
    if data['pago_impuestos'][i]>0 and data['pago_impuestos'][i]<=6:
        estres[i] += 1
    if data['pago_impuestos'][i]>6 and data['pago_impuestos'][i]<=12:
        estres[i] += 2
    if data['pago_impuestos'][i]>12 and data['pago_impuestos'][i]<=18:
        estres[i] += 3
    if data['pago_impuestos'][i]>18 and data['pago_impuestos'][i]<=24:
        estres[i] += 4
        
#pago_credito
for i in range(0, len(data)):
    if data['pago_creditos'][i] == 100 or data['pago_creditos'][i] == 101  or data['pago_creditos'][i] == 102:
        estres[i] += 0
    if data['pago_creditos'][i]>0 and data['pago_creditos'][i]<=6:
        estres[i] += 1
    if data['pago_creditos'][i]>6 and data['pago_creditos'][i]<=12:
        estres[i] += 2
    if data['pago_creditos'][i]>12 and data['pago_creditos'][i]<=18:
        estres[i] += 3
    if data['pago_creditos'][i]>18 and data['pago_creditos'][i]<=24:
        estres[i] += 4
#pago_renta
for i in range(0, len(data)):
    if data['pago_renta'][i] == 100 or data['pago_renta'][i] == 101  or data['pago_renta'][i] == 102:
        estres[i] += 0
    if data['pago_renta'][i]>0 and data['pago_renta'][i]<=6:
        estres[i] += 1
    if data['pago_renta'][i]>6 and data['pago_renta'][i]<=12:
        estres[i] += 2
    if data['pago_renta'][i]>12 and data['pago_renta'][i]<=18:
        estres[i] += 3
    if data['pago_renta'][i]>18 and data['pago_renta'][i]<=24:
        estres[i] += 4
#pago_internet
for i in range(0, len(data)):
    if data['pago_internet'][i] == 100 or data['pago_internet'][i] == 101  or data['pago_internet'][i] == 102:
        estres[i] += 0
    if data['pago_internet'][i]>0 and data['pago_internet'][i]<=6:
        estres[i] += 1
    if data['pago_internet'][i]>6 and data['pago_internet'][i]<=12:
        estres[i] += 2
    if data['pago_internet'][i]>12 and data['pago_internet'][i]<=18:
        estres[i] += 3
    if data['pago_internet'][i]>18 and data['pago_internet'][i]<=24:
        estres[i] += 4
#pago_agua
for i in range(0, len(data)):
    if data['pago_agua'][i] == 100 or data['pago_agua'][i] == 101  or data['pago_agua'][i] == 102:
        estres[i] += 0
    if data['pago_agua'][i]>0 and data['pago_agua'][i]<=6:
        estres[i] += 1
    if data['pago_agua'][i]>6 and data['pago_agua'][i]<=12:
        estres[i] += 2
    if data['pago_agua'][i]>12 and data['pago_agua'][i]<=18:
        estres[i] += 3
    if data['pago_agua'][i]>18 and data['pago_agua'][i]<=24:
        estres[i] += 4

#pago_luz
for i in range(0, len(data)):
    if data['pago_luz'][i] == 100 or data['pago_luz'][i] == 101  or data['pago_luz'][i] == 102:
        estres[i] += 0
    if data['pago_luz'][i]>0 and data['pago_luz'][i]<=6:
        estres[i] += 1
    if data['pago_luz'][i]>6 and data['pago_luz'][i]<=12:
        estres[i] += 2
    if data['pago_luz'][i]>12 and data['pago_luz'][i]<=18:
        estres[i] += 3
    if data['pago_luz'][i]>18 and data['pago_luz'][i]<=24:
        estres[i] += 4

#pago_gas
for i in range(0, len(data)):
    if data['pago_gas'][i] == 100 or data['pago_gas'][i] == 101  or data['pago_gas'][i] == 102:
        estres[i] += 0
    if data['pago_gas'][i]>0 and data['pago_gas'][i]<=6:
        estres[i] += 1
    if data['pago_gas'][i]>6 and data['pago_gas'][i]<=12:
        estres[i] += 2
    if data['pago_gas'][i]>12 and data['pago_gas'][i]<=18:
        estres[i] += 3
    if data['pago_gas'][i]>18 and data['pago_gas'][i]<=24:
        estres[i] += 4
        
#duracion
for i in range(0, len(data)):
    if  data['pago_gas'][i] == 12 or data['pago_gas'][i] == 102:
        estres[i] += 0
    if data['pago_gas'][i]>0 and data['pago_gas'][i]<=6:
        estres[i] += 1
    if data['pago_gas'][i]>6 and data['pago_gas'][i]<=12:
        estres[i] += 2
    if data['pago_gas'][i]>12 and data['pago_gas'][i]<=18:
        estres[i] += 3
    if data['pago_gas'][i]>18 and data['pago_gas'][i]<=24:
        estres[i] += 4
        
#capacidad_pago
for i in range(0, len(data)):
    if data['capacidad_pago'][i] == 'Sí':
        estres[i] += 1
    if data['capacidad_pago'][i] == 'No':
        estres[i] += 2
    if data['capacidad_pago'][i] == 'No sé':
        estres[i] += 0

#credito
for i in range(0, len(data)):
    if data['credito'][i] == 'Sí':
        estres[i] += 2
    if data['credito'][i] == 'No':
        estres[i] += 0
        
#aumento_insumos
for i in range(0, len(data)):
    if data['aumento_insumos'][i] == 'Sí':
        estres[i] += 3
    if data['aumento_insumos'][i] == 'No':
        estres[i] += 0
        
#aumento_precios
for i in range(0, len(data)):
    if data['aumento_precios'][i] == 'Sí':
        estres[i] += 3
    if data['aumento_precios'][i] == 'No':
        estres[i] += 0
        
#escasez_insumos
for i in range(0, len(data)):
    if data['escasez_insumos'][i] == 'Sí':
        estres[i] += 3
    if data['escasez_insumos'][i] == 'No':
        estres[i] += 0
        
#aumento_tipocambio
for i in range(0, len(data)):
    if data['aumento_tipocambio'][i] == 'Sí':
        estres[i] += 4
    if data['aumento_tipocambio'][i] == 'No':
        estres[i] += 0

# %%
data['Estrés'] = estres
data.to_excel('datos_estres.xlsx', sheet_name='estrés')

# %%
data_filter = data[data['Municipio']=='Tlaquepaque']
data_filter
# Out:
#       Folio    Municipio       CP        Sector  \
# 0         1  Tlaquepaque  45608.0      Comercio
# 49       86  Tlaquepaque  45645.0     Servicios
# 62      107  Tlaquepaque  45000.0     Servicios
# 93      179  Tlaquepaque  45580.0   Manufactura
# 122     230  Tlaquepaque  45500.0      Comercio
#
#                                                   Giro  ventas_porcentaje  \
# 0                                                 Otro                 60
# 49                               Consultorios dentales                 80
# 62                                        Restaurantes                100
# 93                    Fabricación de envases de cartón                 80
# 122                                               Otro                 80
# 130              Fertilizantes, plaguicidas y semillas                 30
# 142                                         Papelerías                 90
# 147                         Reparación de electrónicos                 60
# 256                                           Escuelas                 70
# 285                                 Taquerías y Tortas                 40
# 318                                 Talleres Mecánicos                 30
# 363                               Consultorios médicos                 70
# 480                                 Agencias de viajes                 90
# 505              Elaboración de piezas para maquinaria                 60
# 554        Estéticas, salones de belleza y peluquerías                 80
# 567                                               Otro                100
# 576                                               Otro                 90
# 600                                         Papelerías                 80
# 604                                               Otro                 80
# 636                                               Otro                 50
# 683                                         Papelerías                 80
# 707                                               Otro                 80
# 769                                       Restaurantes                 40
# 801                                               Otro                 80
# 858                                         Papelerías                 80
# 867                                               Otro                 70
# 906                                          Farmacias                 60
# 914                                               Otro                 70
# 926                                       Veterinarias                 35
# 933                                               Otro                 70
# ...                                                ...                ...
# 1241                                              Otro                 80
# 1259                        Reparación de electrónicos                 60
# 1274                                              Otro                 75
# 1296                                              Otro                 40
# 1333                                              Otro                 50
# 1339                                              Otro                 90
# 1367                                              Otro                 50
# 1375                                          Escuelas                 70
# 1390                                              Otro                 20
# 1405                                       Gasolineras                 60
# 1437                            Fabricación de muebles                100
# 1442                                              Otro                 95
# 1469                                              Otro                100
# 1472                                              Otro                 30
# 1500                                              Otro                998
# 1506                            Fabricación de muebles                 60
# 1508                                              Otro                 40
# 1530  Fabricación de envases de plástico para embalaje                 20
# 1562                                              Otro                 75
# 1587                                              Otro                 90
# 1593                            Fabricación de muebles                 98
# 1630                                              Otro                100
# 1660                                              Otro                 10
# 1662                                      Restaurantes                 85
# 1748                                              Otro                100
# 1755                            Fabricación de muebles                 95
# 1820                       Equipo y material eléctrico                 50
# 1867                                   Tiendas de ropa                999
# 1905                                              Otro                 50
# 1949                                              Otro                 70
#
#       perdidas_porcentaje  capacidad cerrar  \
# 0                     998         40     No
# 49                     80         20     Sí
# 62                    100          0     Sí
# 93                     90         10     Sí
# 122                    80         50     Sí
# 130                    60         70     No
# 142                    60          0     No
# 147                    50         35     No
# 256                    40         10     No
# 285                    30         60     No
# 318                    50         70     No
# 363                    80         15     Sí
# 480                    30         10     No
# 505                    30         25     Sí
# 554                   100          0     Sí
# 567                    75          0     Sí
# 576                   998          0     Sí
# 600                    80         10     Sí
# 604                    80         40     Sí
# 636                    50         50     No
# 683                    80         20     Sí
# 707                    80         20     Sí
# 769                    40         60     No
# 801                    80         30     Sí
# 858                    70         50     Sí
# 867                    50         30     No
# 906                    60         40     No
# 914                    40         20     No
# 926                    30         50     No
# 933                    50         40     No
# ...                   ...        ...    ...
# 1241                   27         90     No
# 1259                   50         50     No
# 1274                   80         20     No
# 1296                   80         30     No
# 1333                   70          0     No
# 1339                   95          5     No
# 1367                   98          2     Sí
# 1375                   50          0     No
# 1390                   35         60     No
# 1405                   35         50     No
# 1437                   50          0     No
# 1442                   95          1     No
# 1469                   70         20     No
# 1472                   10         90     No
# 1500                  998         90     No
# 1506                   40          0     No
# 1508                   60         60     No
# 1530                   15         85     No
# 1562                   35         50     No
# 1587                   90         10     No
# 1593                   20          0     No
# 1630                  100         50     Sí
# 1660                   10         50     No
# 1662                   70         10     No
# 1748                  100          0     Sí
# 1755                   80          0     Sí
# 1820                   15         35     No
# 1867                  999        999     Sí
# 1905                   50         50     No
# 1949                   50         30     No
#
#                                          despidos   ...    pago_gas  duracion  \
# 0                                              No   ...          12        12
# 49                         No cuenta con personal   ...         101         2
# 62                                             Sí   ...           0         0
# 93                                             No   ...           0         2
# 122                        No cuenta con personal   ...           0         1
# 130                 No, pero lo está considerando   ...           1         0
# 142                        No cuenta con personal   ...         100         1
# 147                        No cuenta con personal   ...           1         0
# 256                                            No   ...           0         2
# 285                                            No   ...           1         1
# 318                 No, pero lo está considerando   ...           2         1
# 363                                            Sí   ...           0         1
# 480                 No, pero lo está considerando   ...           1         1
# 505                 No, pero lo está considerando   ...           0         0
# 554                                            Sí   ...           1         1
# 567   No, pero lo va a hacer en los próximos días   ...           0         1
# 576                        No cuenta con personal   ...           0         0
# 600                        No cuenta con personal   ...           0         2
# 604                 No, pero lo está considerando   ...           2         1
# 636                 No, pero lo está considerando   ...           4         1
# 683                                            No   ...           1         1
# 707                                            Sí   ...           0         1
# 769                 No, pero lo está considerando   ...           2         3
# 801                 No, pero lo está considerando   ...           0         0
# 858                                            No   ...         100         0
# 867                                            No   ...         101         0
# 906                                            No   ...           0         1
# 914                 No, pero lo está considerando   ...           4         2
# 926                                            No   ...           2         6
# 933                 No, pero lo está considerando   ...           0         1
# ...                                           ...   ...         ...       ...
# 1241                                           No   ...          12         4
# 1259                No, pero lo está considerando   ...         100         4
# 1274                No, pero lo está considerando   ...         100         3
# 1296                No, pero lo está considerando   ...           0         1
# 1333                                           No   ...          10         0
# 1339                No, pero lo está considerando   ...           1         2
# 1367                No, pero lo está considerando   ...           1         1
# 1375                No, pero lo está considerando   ...         101         2
# 1390                                           Sí   ...           2         2
# 1405                No, pero lo está considerando   ...           3         2
# 1437                No, pero lo está considerando   ...           1         1
# 1442                No, pero lo está considerando   ...           1         0
# 1469                No, pero lo está considerando   ...           2         1
# 1472                                           No   ...           1         2
# 1500                                           No   ...         100       102
# 1506                No, pero lo está considerando   ...           0         1
# 1508                No, pero lo está considerando   ...           2         1
# 1530                No, pero lo está considerando   ...           0         5
# 1562                                           No   ...         101         0
# 1587                No, pero lo está considerando   ...           1         1
# 1593  No, pero lo va a hacer en los próximos días   ...           3         1
# 1630                                           No   ...           0         2
# 1660  No, pero lo va a hacer en los próximos días   ...           0         1
# 1662                                           No   ...           0         1
# 1748                                           Sí   ...         100         1
